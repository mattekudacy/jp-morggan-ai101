# %% [markdown]
# # Lesson 6:  Scikit-Learn Preprocessing and  TensorFlow Basics

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (2.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.22.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.42.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (12.0.0)
# Requirement already satisfied: absl-py>=0.4.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.35.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: six>=1.12.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: numpy>=1.14.5 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.19.2)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: tensorboard~=2.6 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (2.3.3)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (50.3.1.post20201107)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (2.24.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.4.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/jeffreycostales/opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/Users/jeffreycostales/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
data=np.random.randint(0,100,(10,2))

# %%
data
# Out:
# array([[58, 81],
#        [43, 10],
#        [83, 64],
#        [ 5, 80],
#        [25,  1],
#        [42, 63],
#        [50, 60],
#        [33,  1],
#        [ 1, 72],
#        [ 3, 83]])

# %%
scaler_model=MinMaxScaler()

# %%
type(scaler_model)
# Out:
# sklearn.preprocessing._data.MinMaxScaler

# %%
scaler_model.fit(data)
# Out:
# MinMaxScaler()

# %%
scaler_model.transform(data)
# Out:
# array([[0.69512195, 0.97560976],
#        [0.51219512, 0.1097561 ],
#        [1.        , 0.76829268],
#        [0.04878049, 0.96341463],
#        [0.29268293, 0.        ],
#        [0.5       , 0.75609756],
#        [0.59756098, 0.7195122 ],
#        [0.3902439 , 0.        ],
#        [0.        , 0.86585366],
#        [0.02439024, 1.        ]])

# %%
scaler_model.fit_transform(data)
# Out:
# array([[0.69512195, 0.97560976],
#        [0.51219512, 0.1097561 ],
#        [1.        , 0.76829268],
#        [0.04878049, 0.96341463],
#        [0.29268293, 0.        ],
#        [0.5       , 0.75609756],
#        [0.59756098, 0.7195122 ],
#        [0.3902439 , 0.        ],
#        [0.        , 0.86585366],
#        [0.02439024, 1.        ]])

# %%
import pandas as pd

# %%
mydata = np.random.randint(0,101,(50,4))

# %%
mydata
# Out:
# array([[  6,  18,  28,  62],
#        [ 98,  58,  76,  22],
#        [ 59,  35,  43,  59],
#        [ 54,  48,  56,  38],
#        [ 43,  77,  23,  54],
#        [  4,  98,  14,  19],
#        [ 63,  84,  13,  22],
#        [ 52,  85,  41,  48],
#        [ 71,  43,  48,  86],
#        [ 61,  66,  22,   6],
#        [ 15,  89, 100,  82],
#        [ 59,  87,  45,  58],
#        [ 81,   6,  41,  56],
#        [ 97,  53,  27,  83],
#        [ 68,  40,  71,  94],
#        [ 54,  58,  32,  20],
#        [ 10,   3,  49,  14],
#        [ 73,  97,  20,   1],
#        [ 65,  50,  69,  43],
#        [ 93,  77,  34,  47],
#        [ 43,  43,  46,   7],
#        [ 36,  38,  44,  26],
#        [ 74,  49,  10,  42],
#        [ 25,  19,   3,  81],
#        [ 75,  24,  16,  36],
#        [ 93,  21,  36,  55],
#        [ 80,  22,  93,  63],
#        [ 63,  84,  37,  34],
#        [ 59,   0,  15,  70],
#        [ 47,  95,  95,  26],
#        [ 82,  37,  18,  14],
#        [ 74,  87,  87,  99],
#        [ 80,  90,  82,  21],
#        [ 41,   7,   2,  26],
#        [ 78,  58,  80,  56],
#        [ 13,  58,  13,  51],
#        [ 99,  52,   4,  88],
#        [ 54,  43,  78,  27],
#        [ 22,  25,  39,  50],
#        [ 16,  28,  84,  88],
#        [ 48,  58,  29,   9],
#        [ 19,  86,  16,  38],
#        [ 28,  58,  19,  16],
#        [  1,  43,  17,   3],
#        [ 59,  38,  41,  69],
#        [ 56,  16,  35,  37],
#        [ 99,  80,  16,  45],
#        [ 38,  76,  27,  37],
#        [ 45,  83,   0,  64],
#        [ 91,  65, 100,  82]])

# %%
df = pd.DataFrame(data=mydata,columns=['f1','f2','f3','label'])

# %%
df
# Out:
#     f1  f2   f3  label
# 0    6  18   28     62
# 1   98  58   76     22
# 2   59  35   43     59
# 3   54  48   56     38
# 4   43  77   23     54
# 5    4  98   14     19
# 6   63  84   13     22
# 7   52  85   41     48
# 8   71  43   48     86
# 9   61  66   22      6
# 10  15  89  100     82
# 11  59  87   45     58
# 12  81   6   41     56
# 13  97  53   27     83
# 14  68  40   71     94
# 15  54  58   32     20
# 16  10   3   49     14
# 17  73  97   20      1
# 18  65  50   69     43
# 19  93  77   34     47
# 20  43  43   46      7
# 21  36  38   44     26
# 22  74  49   10     42
# 23  25  19    3     81
# 24  75  24   16     36
# 25  93  21   36     55
# 26  80  22   93     63
# 27  63  84   37     34
# 28  59   0   15     70
# 29  47  95   95     26
# 30  82  37   18     14
# 31  74  87   87     99
# 32  80  90   82     21
# 33  41   7    2     26
# 34  78  58   80     56
# 35  13  58   13     51
# 36  99  52    4     88
# 37  54  43   78     27
# 38  22  25   39     50
# 39  16  28   84     88
# 40  48  58   29      9
# 41  19  86   16     38
# 42  28  58   19     16
# 43   1  43   17      3
# 44  59  38   41     69
# 45  56  16   35     37
# 46  99  80   16     45
# 47  38  76   27     37
# 48  45  83    0     64
# 49  91  65  100     82

# %%
X=df[['f1','f2','f3']]

# %%
y=df['label']

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split(*arrays, **options)>
